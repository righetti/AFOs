# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pylab as plt

import importlib

import pyafos

# %%
# importlib.reload(pyafos)
K =  10000.
omegaF = 30
lamb = 1.
dt = 0.00001
save_dt = 0.001
t_end = 20.

oscill = pyafos.PhaseAFO()

# %%
oscill.initialize(K,omegaF,lamb)
init = np.array([0,10.])
oscill.integrate(0.,t_end,init,dt,save_dt)

# %%
t = oscill.t()
phi = oscill.y()[0,:]
omega = oscill.y()[1,:]
plt.subplot(2,1,1)
plt.plot(t, phi)
plt.subplot(2,1,2)
plt.plot(t, omega)

om = omega[10000:]
print( (lamb*np.min(om) - omegaF)/lamb)
print( (lamb*np.max(om) - omegaF)/lamb)
print((lamb*np.mean(om) - omegaF)/lamb)
# Out:
# <img src="data:image/png;base64,..." width="640">
# -1.3675778588798195
# 1.4977167448138395
# 0.0031872223214612916

# %%
t = oscill.t()

# %%
t
# Out:
# array([0.0000e+00, 1.0000e-03, 2.0000e-03, ..., 1.9997e+01, 1.9998e+01,
#        1.9999e+01])
